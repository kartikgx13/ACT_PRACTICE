# %%
"""
Application of expression tree:
Used for internal calculations in programs

Level of precedence:
(**)-->(*)-->(/)-->(%)-->(+)-->(-)
  3     2     2     2     1     1

"""

# %%
"""
Multiway Search tree:
-->a node can keep more than one element hence multiway

Importance of multiway search tree:
-->node capacity increased made us capable of storing
more than 1 element at a node

Multiway search tree has order M(must be odd)
-->Minimum elements(M/2)
-->Maximum elements(M-1 split M)

-->inserting done only in leaf inorder using BST logic
--child will create parent and parent will
create grand parent.

Mainly used for storage i.e. storing multiple storage values
at single node

"""

# %%
"""
Deletion:
-->Parent with both subtree
Soln:Inorder next takes over
That is the number next to the del node in inorder
traversal will take its place and rest of the tree will be as it
is according to rules of BST

"""

# %%
"""
Binary tree implementation:
can be done in 3 ways:
-->static array(root at 0,for each ith left child is at 2i+1,for each ith right child is at 2i+2)
-->doubly linked list
-->using tree nodes

The first one can be asked in a way like:
How can u implement heirarchial structure using
flat structure/linear structure

Adv:simple
Disadv:Static

2.DLL node approach:
Adv:This is dynamic and scalable
Disadv:only top to bottom access because from leaf nodes
there is no access to root nodes
Therefore recursion is used but again it is disadvantage

3.Tree node implementation:
Here in addition to DLL node there is a reference to parent also
so in total 3 references that is left and right and parent

Adv:Dynamic and can grow as per need,memory friendly
Disadv:too complex to use

"""

# %%
"""
Imp question:
1.Which one would u prefer?
Ans.If simplicity is needed and size of tree is known then 
stack
If dynamicity is needed and recursion is bearable then DLL approach
If we are ready to accept complexity of code then
tree node approach.

"""

# %%
"""
Graphs:
Imp: Study all important applications of graphs

-->Graph is a collection of nodes and edges where edges 
relates all the nodes
-->Every tree is a graph 
-->Graph without cylce is a tree
-->Tree is a subset of graph

There are various types of graph:
Weighted and Unweighted
Directed and Undirected

1.Unweighted and Undirected:Shows only connections

2.Weighted and Undirected:In addition to above there is edge cost
any unit that can be used to make decisions

3.Unweighted and Directed:There is source and
destination

4.Weighted and Directed:There is source and destination
and we operate through edge costs(widely used in decision making problems)

Imp question:
Why are weights are non symmetric in weighted and directed:
Give the traffic eg.
"""

# %%
"""
-->Adjacent node:Two nodes are adjacent if they are
connected by an edge
-->Path:A sequence of vertices that connects two nodes in
the graph
-->Cycle:The path which starts and end in same vertex
-->Complete graph:A graph in which every vertex is connected
to other vertices
-->Degree is  defined as no. of nodes connected directly to a node

-->In directed degree it will be in and out degree
-->A self loop will add one each in in and out degree

What is significance of self loop in graph:
Ans.This nodes are mainly used as backup nodes

Applications of Graph:
1.In routing
Types of network:
Wired and Wireless
Connection-oriented and Connection-less
Reliable and Unreliable

2.In Biometric
-->A graph is used to scan the face

3.Searching Algos

4.Handling flow problems:

5.Topological Sort:
-->Sequence of operations which need to be in order

6.Google Maps

"""
